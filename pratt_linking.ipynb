# %% [markdown]
# # Polifonia-Pratt alignment
#
# Align polifonia JAAH recording artists with Pratt linked-jazz database names
# https://github.com/polifonia-project/datasets <-> https://triplydb.com/pratt/linked-jazz/
#
# Two steps:
# 1. Match recording_meta names to pratt linked jazz people names
# 2. Validate match pairs by additional information
#     - query both elements of the pair for birth/death dates and places
#     - consider a match valid if at least one field perfectly matches
#
# Data in brief:
# - 510 recording_meta related artists
# - 2005 pratt people names
#
# Results in brief:
# 1. name-only: 220 matches (takes approx. 1 minute)
# 2. query validated: 189 matches by name and at-least-one field match (takes approx. 5 minutes)

# %%
# PATHS
LINKED_JAZZ_PATH = "pratt_linked_jazz/linked-jazz.trig"
DATA_MAP_PATH = "data_map.csv"

#RECORDINGS_PATH = "datasets-main/dataset/jaah/cornucopia_data/musicbrainz/" 
RECORDINGS_PATH = "jaah_recording_meta/"

OUTPUT_1 = "outputs/sameas_by_names.txt"
OUTPUT_2 = "outputs/sameas_by_sparql.txt"

# %%
# name match
# !pip install pandas -q
# !pip install nltk -q

import json
import pandas as pd
from nltk.metrics import distance

# match validation
# !pip install requests -q
# !pip install sparqlwrapper -q
import requests
from SPARQLWrapper import SPARQLWrapper, JSON

# %% [markdown]
# ## Name Match
# ### Pratt file
# Pratt linked-jazz.trig database is a trig file:
# a Turtle-like format for RDF triples + context (RDF quads) and thus multiple graphs.
#
# #### Pratt people
# People information is stored in the first part of the file, under '<https://triplydb.com/pratt/linked-jazz/id/graph/people>' graph.
# It is made of subject- predicate- object triples where:
#
# subjects are:
# - <http://dbpedia.org/resource/Zutty_Singleton>
# - <http://id.loc.gov/authorities/names/n00064734>
# - <http://linkedjazz.org/resource/Adam_Lambert>
# - <http://musicbrainz.org/artist/03df380a-665d-48c6-9cee-90c53f40ec3b>
# - <http://www.allmusic.com/artist/angelo-tompros-mn0000868923>
#
# predicates are:
# - sub <http://xmlns.com/foaf/0.1/name>
# - sub <http://dbpedia.org/ontology/thumbnail>
#
#
#
# Every single entry has a foaf name, like:
# sub <http://xmlns.com/foaf/0.1/name> "Zsa Zsa Gabor"@en .
# And many have a thumbnail:
# sub <http://dbpedia.org/ontology/thumbnail> <http://linkedjazz.org/image/square/Zutty_Singleton.png> .
#
# Thus: every Pratt People name can be extracted by its foaf:name object.

# %%
# list pratt artists by foaf:name:

# 1 read the prat linked-jazz .trig file as plain text
# 2 read people triplets line-by-line, skip first and stop at '}'
# populate pratt_people names by cleaning each line string after foaf:name prefix

with open(LINKED_JAZZ_PATH,"r") as f:
    pratt_file = f.readlines()

flag = 0
#pratt_people = []
pratt_iris = []
pratt_people = {}
count=0
for i, line in enumerate(pratt_file):
    if line == '}': break #end of people
    if '<http://xmlns.com/foaf/0.1/name>' in line:
        line = line.split('<http://xmlns.com/foaf/0.1/name>')

        iri = line[0].strip()
        person = line[-1].split('"')[1]

        if not pratt_people.get(iri):
            pratt_people[iri] = person
            count +=1
        else:
            #pratt_people[iri] += [person]
            count +=1
            print('duplicate name:', iri, pratt_people[iri])
        #pratt_people.append(person)
        #pratt_iris.append(iri)
        #flag +=1
        #if flag >=5: break

print(f"\nPratt has {len(pratt_people)} people entries with {count} name aliases")
# Out:
# duplicate name: <http://dbpedia.org/resource/Fantasy_Records> Max Weiss
# duplicate name: <http://dbpedia.org/resource/Martin_Luther_King,_Jr.> Martin Luther King Jr
# duplicate name: <http://id.loc.gov/authorities/names/no98012278> Argonne Thornton
#
# Pratt has 2005 people entries with 2008 name aliases

# %%
# data_map.csv stores each recording .json file name
df = pd.read_csv(DATA_MAP_PATH)
df.head(2)
# Out:
#                      artist     track_name jaah/chord_annotation  \
# 0           Thelonious Monk       Evidence         evidence.jams
# 1  Charlie Parker All-Stars  Parker's Mood     parkers_mood.jams
#
#   genius/lyrics genius/lyrics_annotation  \
# 0            NF                       NF
# 1            NF                       NF
#
#                             musicbrainz/work_meta  \
# 0  work_f1875b4c-ac07-3614-9bd2-4259e1865f07.json
# 1  work_93618e9e-4bf8-3cd9-8b72-258750d4222c.json
#
#                           musicbrainz/recording_meta  \
# 0  recording_b438e7a3-91b9-4e43-9551-03b07036f3f3...
# 1  recording_c50ea630-b5f0-4c12-8e75-0321757d69a3...
#
#                             musicbrainz/release_meta  \
# 0  release_e65a3c02-84c4-41b8-802f-71b5d42ac92a.json
# 1  release_a90eeed6-dc07-4173-938c-49e63142f299.json
#
#                             musicbrainz/artist_meta  \
# 0  artist_b438e7a3-91b9-4e43-9551-03b07036f3f3.json
# 1  artist_c50ea630-b5f0-4c12-8e75-0321757d69a3.json
#
#   secondhandsong/artist_meta sonar_id
# 0              shs_2288.json  jaah_76
# 1                         NF  jaah_78

# %%
len(pratt_people.values()), list(pratt_people.values())[:5]
# Out:
# (2005,
#  ['Aaron Copland',
#   'Abbey Lincoln',
#   'Abdullah Ibrahim',
#   'Adele Girard',
#   'Agatha Christie'])

# %%
# check if aartist column matches with pratt people
count_matches = 0
for artist in df['artist']:
    if artist in pratt_people.values(): count_matches +=1
print(count_matches)

assert 'Charlie Parker' in pratt_people.values()

print(df['artist'][1],  "!= Charlie Parker")
# Out:
# 25
# Charlie Parker All-Stars != Charlie Parker

# %% [markdown]
# Match count by 'aartist' column are very low.
# This is because they are usually expressed as main artist + band:
# - Charlie Parker All-Stars,
# - Jelly Roll Morton's Red Hot Peppers etc.

# %% [markdown]
# ### Recording_meta vs Pratt alignment
# The following method retrieves all artists related to the 'recording_meta' files we have

# %%
def recording_names(df):
    """List all artist names related to the recordings in df"""

    artist_names = {}
    for i in range(len(df)):
        json_path = df.loc[i,'musicbrainz/recording_meta']
        
        with open(os.path.join(RECORDINGS_PATH, json_path),'r') as json_file:
            json_entry = json.load(json_file)

        for artist in json_entry['recording']['artist-relation-list']:
            artist_names[artist['artist']['id']] = artist['artist']['name']
            #artist_names.append(b['artist']['name'])
            #print(b['artist']['id'])
    return artist_names

recording_artists = recording_names(df)
#recording_artists = list(set(recording_artists)) #deduplicate

print(f"Found {len(recording_artists)} artists in recording meta files")
# Out:
# Found 510 artists in recording meta files

# %%
pratt_people_dbpedia ={}
for person in pratt_people.items():
    if person[0].startswith('<http://dbpedia.org/'):
        pratt_people_dbpedia[person[0]] = person[1]
len(pratt_people_dbpedia)
# Out:
# 1516

# %%
count_matches = 0

for artist in recording_artists.values():
    if artist in pratt_people.values():
        count_matches +=1

print(f"Found {count_matches} perfect matches by name")
# Out:
# Found 231 perfect matches by name

# %% [markdown]
# ### Edit distance matching
#
# Checking perfect match already gives good results, but many artists are left unmatched.
# If no perfect match exists for a given recording artist, edit distance is computed to every pratt people name.
#
# The best candidate is selected and the (artist, distance, pratt_people) is returned.
# Non-perfect matches are added to possible_matches list, to possibly add later.

# %%
# not used now
strange = []
for a in recording_artists.items():
    name = a[1]
    #print(name)
    if '"' in name or '.' in name:
        #print(name)
        strange.append(a)

for strange_name in strange:
    print(strange_name)
    name = strange_name[1]
    print(name)
    name = name.split()
    newname = []
    for substring in name:
        if not '"' in substring and '.' not in substring:
            newname.append(substring)
    newname = ' '.join(newname).strip(',')
    print(newname)
    print()
# Out:
# ('7a281c93-adc9-4426-9331-f5e870162f91', 'Johnny St. Cyr')
# Johnny St. Cyr
# Johnny Cyr
#
# ('b1669585-019f-483d-80c2-caada4275157', 'Joe "Tricky Sam" Nanton')
# Joe "Tricky Sam" Nanton
# Joe Nanton
#
# ('2a58b026-9659-4bfb-90c9-56c4ad9125f1', 'James P. Johnson')
# James P. Johnson
# James Johnson
#
# ('33e50556-d4be-421b-a5d1-644bd536ec07', 'J.J. Johnson')
# J.J. Johnson
# Johnson
#
# ('63ca22b3-b010-45d6-99bf-fd205829a645', 'Sanford J. Siegelstein')
# Sanford J. Siegelstein
# Sanford Siegelstein
#
# ('6c097081-53d9-417f-a169-2eface036ca7', 'George "Pops" Foster')
# George "Pops" Foster
# George Foster
#
# ('f661cb81-305e-421d-bac0-c02f6056d824', 'L. Z. Cooper')
# L. Z. Cooper
# Cooper
#
# ('a7ed66a4-9ddd-430a-9797-be4ca4199eb3', 'Louis R. Mucci')
# Louis R. Mucci
# Louis Mucci
#
# ('9c0e864c-f356-4ebc-98af-0a45cd7801b9', 'Billy Taylor Sr.')
# Billy Taylor Sr.
# Billy Taylor
#
# ('58bc629e-b6d2-47a6-ab11-4f6d64c6f7fe', 'Mancy "Peck" Carr')
# Mancy "Peck" Carr
# Mancy Carr
#
# ('10eb67e5-8594-41e9-a691-3b7d3a9da907', 'Roy "Red" Maier')
# Roy "Red" Maier
# Roy Maier
#
# ('de687ea9-6d7f-4d0e-9390-8bfbc8ffad11', 'Austin "Skin" Young')
# Austin "Skin" Young
# Austin Young
#
# ('14786e41-9591-47a2-b8f4-a7cd50b6ae8b', 'Howard E. Johnson')
# Howard E. Johnson
# Howard Johnson
#
# ('43821ad7-981e-4167-961e-bad1110c3e30', 'George "Big Nick" Nicholas')
# George "Big Nick" Nicholas
# George Nicholas
#
# ('75bda783-d2dd-4db4-9ba7-126e3bbb596d', 'Lammar Wright, Jr.')
# Lammar Wright, Jr.
# Lammar Wright
#
# ('24538ec6-ab66-4403-9e59-2d238ae7de3f', 'David "Piro" Rodríguez')
# David "Piro" Rodríguez
# David Rodríguez
#
# ('6277beee-cd16-4c7d-a29b-af7e179a35a7', 'Adolphe "Tats" Alexander Jr.')
# Adolphe "Tats" Alexander Jr.
# Adolphe Alexander
#
# ('058f47da-cae5-463e-bb1c-578522b3c86b', 'Joe "Red" Clark')
# Joe "Red" Clark
# Joe Clark
#
# ('8e608418-bb31-427d-ad20-89c2f6d877a5', 'Louis "Kid Shots" Madison')
# Louis "Kid Shots" Madison
# Louis Madison
#
# ('8e696cb7-cf20-4c66-ac25-dac7774df07b', 'Eddie Heywood, Jr.')
# Eddie Heywood, Jr.
# Eddie Heywood
#
# ('7418d518-f0e4-48da-aebc-555a45020c08', 'Leroy "Buster" Berry')
# Leroy "Buster" Berry
# Leroy Berry
#
# ('249f83c8-b05f-4963-83dd-af1e2cf27fac', 'Ira E. "Buster" Moten')
# Ira E. "Buster" Moten
# Ira Moten
#
# ('4c42e4ee-6bc1-4b4e-a77b-75570e004838', 'Prince "Dee" Stewart')
# Prince "Dee" Stewart
# Prince Stewart
#
# ('c4edc877-f1d8-4803-8141-cae1d3ab4c97', 'Leonard "Ham" Davis')
# Leonard "Ham" Davis
# Leonard Davis
#
# ('81503f0d-3435-4281-9068-c97930e1626a', 'Irving "Babe" Russin')
# Irving "Babe" Russin
# Irving Russin

# %%
from collections import namedtuple
def check_match(name, namedict, distance_th=3, loose =False):
    """
    Checks if name distance <= threshold from every element in namelist.
    Returns a (name, distance, candidate) tuple.
    """
    PairDist = namedtuple('PairDist', ['dist', 'y'])
    
    for item in namedict.items():
        if name == item[1]:
            return PairDist(0, item)
        
    else:
        candidates = [] #distance from name, iri of name
        for item in namedict.items():
            
            candidates.append(PairDist(distance.edit_distance(name, item[1]), item))

        candidates.sort(key= lambda x: x[0])

        if candidates[0][0] <= distance_th:
            #print(name, candidates[0])
            return candidates[0]
        else:
            return False

check_match('Thelnius Monk', pratt_people)
# Out:
# PairDist(dist=1, y=('<http://id.loc.gov/authorities/names/n82218969>', 'Thelonius Monk'))

# %%
# check matches for each artist in recording meta

possible_matches = []
perfect_matches = []

for artist in recording_artists.items():
    match = check_match(artist[1], pratt_people, distance_th=3)
    if match:
        if match[0] <= 1: #matched with distance <=1
            perfect_matches.append((artist[0], match[1][0])) #iri, iri
            if match[0] == 1: print(artist, match)
        else:
            possible_matches.append((artist, match))

len(perfect_matches)
# Out:
# ('f0707f1d-55e1-46b6-8a9c-05d508e09a73', 'Rudy van Gelder') PairDist(dist=1, y=('<http://dbpedia.org/resource/Rudy_Van_Gelder>', 'Rudy Van Gelder'))
# ('46435fe9-34c1-4e4e-86ed-cc0bf6c6234d', 'Earle Warren') PairDist(dist=1, y=('<http://dbpedia.org/resource/Earle_Warren>', 'Earl Warren'))
# ('d2de9fbd-1cdf-4212-b5ee-f830f69521de', 'Georgie Auld') PairDist(dist=1, y=('<http://id.loc.gov/authorities/names/n85098932>', 'George Auld'))
# ('6981867e-810d-4a16-96cf-8dfbc734a477', 'Sidney De Paris') PairDist(dist=1, y=('<http://id.loc.gov/authorities/names/n91049777>', 'Sidney DeParis'))
# 235

# %%
# resolve firstname diminutives
aliases = [
    ('Freddie Powell', 'Fred Powell'),
    ('Freddie Powell','Freddy Powell'),
    ('Bob Powell','Bobby Powell'),
    ('Howard E. Johnson','Howard Johnson'),
    ('John Thomas','Joe Thomas'),
    ('Johnny Martel', 'Johnny Mandel')]

aliases_results = [True, True, True, True, False, False]
def check_firstname_diminutive(pair):

    a,b  = pair
    
    if a.split()[-1] != b.split()[-1]:
        #print(pair, False)
        return False # diff surname
    a = a.split()[0].replace('ie','').strip('y')
    b = b.split()[0].replace('ie','').strip('y')

    if a.startswith(b) or b.startswith(a):
        print(pair, True)
        return True
    else:
        #print(pair, False)
        return False

assert [check_firstname_diminutive(pair) for pair in aliases] == aliases_results
# Out:
# ('Freddie Powell', 'Fred Powell') True
# ('Freddie Powell', 'Freddy Powell') True
# ('Bob Powell', 'Bobby Powell') True
# ('Howard E. Johnson', 'Howard Johnson') True

# %%
# resolve possible diminutives with distance < distance_th
checked_matches = []
for (artist, match) in sorted(possible_matches, key= lambda x: x[1][0]):

    if check_firstname_diminutive((artist[1], match[1][1])):
        checked_matches.append((artist[0], match[1][0]))

len(checked_matches), checked_matches
# Out:
# ('Freddy Jenkins', 'Freddie Jenkins') True
# ('Fred Robinson', 'Freddy Robinson') True
# ('Bob Whitlock', 'Bobby Whitlock') True
# ('Dicky Wells', 'Dickie Wells') True
# ('Fred Guy', 'Freddie Guy') True
# ('Howard E. Johnson', 'Howard Johnson') True
# (6,
#  [('a1eb52a1-07d5-4179-91ae-3ee5fe3e19b9',
#    '<http://dbpedia.org/resource/Freddie_Jenkins>'),
#   ('a21a0f9e-89b9-42c4-83d7-8da1295fdef3',
#    '<http://dbpedia.org/resource/Freddy_Robinson>'),
#   ('128eac4c-1724-4ea6-a7c9-c348e89235e1',
#    '<http://dbpedia.org/resource/Bobby_Whitlock>'),
#   ('c43e27c8-3c26-4cea-a39a-9a091aabfd36',
#    '<http://dbpedia.org/resource/Dicky_Wells>'),
#   ('ffd90943-ec19-4b02-8077-1cf2e4221b90',
#    '<http://id.loc.gov/authorities/names/n80124239>'),
#   ('14786e41-9591-47a2-b8f4-a7cd50b6ae8b',
#    '<http://dbpedia.org/resource/Howard_Johnson_(jazz_musician)>')])

# %%
len(perfect_matches) + len(checked_matches)
# Out:
# 241

# %%
perfect_matches += checked_matches
checked_matches = []
len(perfect_matches)
# Out:
# 241

# %%
# save matches to file
os.makedirs(os.path.split(OUTPUT_1)[0], exist_ok=True)
with open(OUTPUT_1,'w') as f:
    for i, pair in enumerate(perfect_matches):
        if i!=0: f.write('\n')
        a, b = pair
        f.write(f"<http://musicbrainz.org/artist/{a}> <owl:sameAs> {b}")

# %% [markdown]
# Some pratt people are identified my musicbrainz IRI, thus we can automatically validate our previous matching on those pairs.

# %%
count = 0
false_matches = 0
with open(OUTPUT_1,'r') as f:
    file = f.readlines()
    for line in file:
        if line.startswith('<http://musicbrainz.org/artist/'):
            a,b,c = line.split()
            if c.startswith('<http://musicbrainz.org/artist/'):
                count +=1
                if a!=c:
                    false_matches+=1
                    print(a.strip('<>')), print(c.strip('<>'))
                    print()

print(f"Total MBID sameAs MBID: {count}, with wrong ones: {false_matches}")
# Out:
# http://musicbrainz.org/artist/258c295b-bae6-433b-955b-b590fe4a571d
# http://musicbrainz.org/artist/755d3c6a-9697-4204-803e-01333b29133e
#
# http://musicbrainz.org/artist/a67b42cc-1dc6-482f-9998-086af20be905
# http://musicbrainz.org/artist/b2a298bc-c4ad-438b-8fc7-36002502706b
#
# Total MBID sameAs MBID: 9, with wrong ones: 2

# %% [markdown]
# This suggests to proceed with further validation of the pairs.

# %% [markdown]
# ## Validate Matches by SPARQL
# by musicbrainz artist json vs dbpedia SPARQL query

# %%
def query_musicbrainz_json(mbid, fields = ['birthdate','deathdate','birthplace','deathplace']):

    """ Query musicbrainz json with requests, return selected fields"""
    mb_json_path = '?inc=aliases&fmt=json'
    mb_json_root = 'https://musicbrainz.org/ws/2/artist/'
    mbid = mbid.replace('http://musicbrainz.org/artist/','')

    url = mb_json_root + mbid + mb_json_path
    #print(url)
    
    response = requests.get(url)

    if (response.status_code != 204 and
        response.headers["content-type"].strip().startswith("application/json")):
        try:
            json_entry = response.json()
        
            queries = {
                'birthdate': ('life-span','begin'),
                'deathdate': ('life-span','end'),
                'birthplace': ('begin-area','name'),
                'deathplace': ('end-area','name')
            }

            results = []
            answer = ''
            if json_entry is not None:
                for i,field in enumerate(fields):
                    try:
                        ll = json_entry.copy()
                        for id in queries[field]: #deep index
                            ll = ll[id]
                        answer = ll or ''
                        #print(answer)
                        results.append(answer)

                    except (TypeError,KeyError): 
                        #print(i,field,'no key in musicbrainz')
                        #print(url)
                        results.append('')
                        continue
                        
                return results

            
        except ValueError:
            print('wrong json')
            return ['']*len(fields)
        

#test
query_musicbrainz_json(mbid='2e38e1de-2890-4620-8467-5b0bb4641cb9',)
# returns [None, None, None,...]
# in case of no json or no fields
# Out:
# ['1923-01-01', '1999-10-09', 'Detroit', 'Manhattan']

# %%
def query_dbpedia_sparql(artist, fields=('birthdate', 'deathdate','birthplace','deathplace')):
    
    queries = {
        'birthdate':    'dbo:birthDate',
        'deathdate':    'dbo:deathDate',
        'birthplace':   'dbo:birthPlace',
        'deathplace':   'dbo:deathPlace'

    }
    
#    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
#
#    query_text = """
#        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#        SELECT"""
#    
#    for query in zip(queries,'abcdefghijklmnopqrstuwxyz'):
#        query_text += ' ?'+query[1]
#
#    query_text += """WHERE {""" # compose multiple query to spare some minutes

    artist = artist.strip('<').strip('>')
    results = []

    for field in fields:
        sparql = SPARQLWrapper("http://dbpedia.org/sparql")
        sparql.setQuery(f"""
            PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
            SELECT ?x
            WHERE {{ <{artist}> {queries[field]} ?x .
                    }}
        """)

        sparql.setReturnFormat(JSON)
        query_results = sparql.query().convert()

        if not query_results["results"]["bindings"]:
            results.append('')
            print('No query answer')###
        else:
            for result in query_results["results"]["bindings"]:
                answer = result['x']['value']
                #continue
                if answer is None:
                    print(f'No {field} field in answer')###
                results.append(answer or '')
                break #TODO handle multiple responses to the same query
    if results == ['']*len(fields): print(artist)
    return results

query_dbpedia_sparql(artist='http://dbpedia.org/resource/Charlie_Parker')
# Out:
# ['1920-08-29',
#  '1955-03-12',
#  'http://dbpedia.org/resource/Kansas_City,_Kansas',
#  'http://dbpedia.org/resource/New_York_City']

# %%
def check_match(match, fields = ('birthdate','deathdate','birthplace','deathplace'), verbose = False):
    """
    Check musicbrainz vs dbpedia fields.
    Return count of matching fields.
    Field match replaces each underscore with whitespace.
    """

    #if verbose: print('musicbrainz')
    r1 = query_musicbrainz_json(match[0], fields)
    #if verbose: print('dbpedia sparql')
    r2 = query_dbpedia_sparql(match[1], fields)

    # r1 list
    # r2 list or list of lists

    match_count = 0
    match = []
    for pair in zip(r1,r2):
        
        if pair[0] != '' and pair[0] in pair[1].replace('_',' '):
            match_count +=1
            match.append(True)
            #print('matching pair', pair)
        else:
            match.append(False)
            #print('non matching', pair)

    if verbose or match_count < len(fields):
        print(r1)
        print(match)
        print(r2)
        print()

    return match_count

for match in perfect_matches[4:5]:
    print(match)
    check_match(match, verbose=True)
# Out:
# ('c7356af9-9ea6-4a78-a55b-c73775716312', '<http://dbpedia.org/resource/Charlie_Parker>')
# ['1920-08-29', '1955-03-12', 'Kansas City', 'New York']
# [True, True, True, True]
# ['1920-08-29', '1955-03-12', 'http://dbpedia.org/resource/Kansas_City,_Kansas', 'http://dbpedia.org/resource/New_York_City']

# %%
query_matches = []
with open(OUTPUT_1,'r') as f:
    file = f.readlines()
    for line in file:
        match = line.replace('<','').replace('>','').strip().split(' owl:sameAs ')
        if check_match(match, fields = ('birthdate','deathdate','birthplace','deathplace')):
            query_matches.append(match)
            #print(match)

print(len(query_matches))
# Out:
# ['1923-01-01', '1999-10-09', 'Detroit', 'Manhattan']
# [True, True, True, False]
# ['1923-01-01', '1999-10-09', 'http://dbpedia.org/resource/Detroit', 'http://dbpedia.org/resource/New_York_City']
#
# ['1924-01-10', '2007-08-15', 'Pasquotank County', 'Manhattan']
# [True, False, True, False]
# ['1924-01-10', '2007-08-16', 'http://dbpedia.org/resource/Pasquotank_County,_North_Carolina', 'http://dbpedia.org/resource/New_York_City']
#
# ['1885-10-20', '1941-07-10', 'New Orleans', 'Los Angeles']
# [False, True, True, True]
# ['1890-09-20', '1941-07-10', 'http://dbpedia.org/resource/New_Orleans', 'http://dbpedia.org/resource/Los_Angeles']
#
# ['1886-12-25', '1973-01-23', 'Louisiana', 'Honolulu']
# [True, True, True, False]
# ['1886-12-25', '1973-01-23', 'http://dbpedia.org/resource/LaPlace,_Louisiana', 'http://dbpedia.org/resource/Hawaii']
#
# ['1891-01-25', '1966-10-29', 'St. James Parish', 'Los Angeles']
# [True, True, True, False]
# ['1891-01-25', '1966-10-29', 'http://dbpedia.org/resource/St._James_Parish,_Louisiana', 'http://dbpedia.org/resource/California']
#
# No query answer
# ['1910-04-01', '1974-10-08', 'Boston', 'New York']
# [True, True, True, False]
# ['1910-04-01', '1974-10-08', 'http://dbpedia.org/resource/Boston', '']
#
# ['1895-12-13', '1982-03-23', 'Long Branch', 'Lenox Hill']
# [True, True, True, False]
# ['1895-12-13', '1982-03-23', 'http://dbpedia.org/resource/Long_Branch,_New_Jersey', 'http://dbpedia.org/resource/Manhattan']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Otto_Hardwick
# ['1904-05-31', '1970-08-05', 'Washington, D.C.', 'Washington, D.C.']
# [False, False, False, False]
# ['', '', '', '']
#
# ['1903-04-03', '1932-05-20', 'Aiken', 'Manhattan']
# [True, True, True, False]
# ['1903-04-03', '1932-05-20', 'http://dbpedia.org/resource/Aiken,_South_Carolina', 'http://dbpedia.org/resource/New_York_City']
#
# ['1897-12-18', '1952-12-28', 'Cuthbert', 'New York']
# [True, False, True, True]
# ['1897-12-18', '1952-12-29', 'http://dbpedia.org/resource/Cuthbert,_Georgia', 'http://dbpedia.org/resource/New_York_City']
#
# No query answer
# ['1909-02-04', '1964-01-04', 'Brooklyn', 'Los Angeles']
# [True, True, True, False]
# ['1909-02-04', '1964-01-04', 'http://dbpedia.org/resource/Brooklyn', '']
#
# ['1914-05-26', '1968-06-26', 'Philadelphia', 'Los Angeles']
# [True, True, False, False]
# ['1914-05-26', '1968-06-26', 'http://dbpedia.org/resource/Pennsylvania', 'http://dbpedia.org/resource/California']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://musicbrainz.org/artist/5c0f8878-5d26-446d-acad-8084816fb8be
# ['1912-06-19', '2001-11-17', 'Brooklyn', 'Sarasota']
# [False, False, False, False]
# ['', '', '', '']
#
# ['1895-04-23', '1944-04-19', 'New Orleans', 'Los Angeles']
# [True, True, False, False]
# ['1895-04-23', '1944-04-19', 'http://dbpedia.org/resource/Cut_Off,_Louisiana', 'http://dbpedia.org/resource/California']
#
# No query answer
# ['1910-12-17', '1988-05-28', 'Battle Creek', 'New York']
# [True, True, True, False]
# ['1910-12-17', '1988-05-28', 'http://dbpedia.org/resource/Battle_Creek,_Michigan', '']
#
# ['1902-06-06', '1947-07-12', 'Fulton', 'Seaside']
# [True, True, True, False]
# ['1902-06-06', '1947-07-12', 'http://dbpedia.org/resource/Fulton,_Mississippi', 'http://dbpedia.org/resource/Oregon']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Jimmy_Crawford_(drummer)
# ['1910-01-14', '1980-01-28', 'Memphis', 'New York']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# ['1908-08-19', '1987-03-06', 'San Marcos', 'New York']
# [False, True, True, False]
# ['1906-08-19', '1987-03-06', 'http://dbpedia.org/resource/San_Marcos,_Texas', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://id.loc.gov/authorities/names/no2002100076.html
# ['1910', '1963-03', '', 'Los Angeles']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# ['1910-11-25', '1967-03-07', 'Charleston', 'Los Angeles']
# [False, False, False, False]
# ['1936-01-19', '2011-09-16', 'http://dbpedia.org/resource/Helena,_Arkansas', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Joe_Thomas_(saxophonist)
# ['1909-06-19', '1986-08-03', 'Uniontown', 'Kansas City']
# [False, False, False, False]
# ['', '', '', '']
#
# ['1932-12-10', '2016-11-02', 'Evanston', 'Manhattan']
# [False, True, False, True]
# ['1932-12-03', '2016-11-02', 'http://dbpedia.org/resource/Chicago', 'http://dbpedia.org/resource/Manhattan']
#
# ['1918-07-31', '2010-05-16', 'Vicksburg', 'Manhattan']
# [True, True, True, False]
# ['1918-07-31', '2010-05-16', 'http://dbpedia.org/resource/Vicksburg,_Mississippi', 'http://dbpedia.org/resource/The_Bronx']
#
# ['1901-08-04', '1971-07-06', 'New Orleans', 'Corona']
# [True, True, True, False]
# ['1901-08-04', '1971-07-06', 'http://dbpedia.org/resource/New_Orleans', 'http://dbpedia.org/resource/New_York_City']
#
# No query answer
# ['1892-04-12', '1940-08-08', 'Waveland', 'Chicago']
# [True, True, False, True]
# ['1892-04-12', '1940-08-08', '', 'http://dbpedia.org/resource/Chicago']
#
# No query answer
# No query answer
# ['1930-09-07', '', 'Harlem', '']
# [True, False, False, False]
# ['1930-09-07', '', 'http://dbpedia.org/resource/New_York_City', '']
#
# No query answer
# No query answer
# ['1929-12-15', '2021-12-08', 'Detroit', 'North Bergen']
# [True, False, True, False]
# ['1929-12-15', '', 'http://dbpedia.org/resource/Detroit', '']
#
# No query answer
# ['1924-11-12', '1981-12-15', 'Jacksonville', 'New York']
# [True, True, True, False]
# ['1924-11-12', '1981-12-15', 'http://dbpedia.org/resource/Jacksonville,_Florida', '']
#
# No query answer
# ['1914-01-02', '1985-01-26', 'Pittsburgh', 'Montreuil']
# [False, True, False, True]
# ['1914-01-09', '1985-01-26', '', 'http://dbpedia.org/resource/Montreuil,_Seine-Saint-Denis']
#
# No query answer
# ['1911-11-12', '1991-12-08', 'Parsons', 'New York']
# [True, True, True, False]
# ['1911-11-12', '1991-12-08', 'http://dbpedia.org/resource/Parsons,_Kansas', '']
#
# No query answer
# ['1911-03-31', '1987-03-01', 'Charleston', 'Las Vegas']
# [True, True, True, False]
# ['1911-03-31', '1987-03-01', 'http://dbpedia.org/resource/Charleston,_South_Carolina', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Jo_Jones
# ['1911-10-07', '1985-09-03', 'Chicago', 'New York']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Ed_Lewis_(musician)
# ['1909-01-22', '1985-09-18', 'Oklahoma', 'New York']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Dan_Minor
# ['1909-08-10', '1982-04-11', 'Dallas', 'New York']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Benny_Morton
# ['1907-01-31', '1985-12-28', 'New York', 'New York']
# [False, False, False, False]
# ['', '', '', '']
#
# ['1900-02-09', '1957-12-20', 'Gallatin', 'Manhattan']
# [True, True, True, False]
# ['1900-02-09', '1957-12-20', 'http://dbpedia.org/resource/Gallatin,_Missouri', 'http://dbpedia.org/resource/New_York_City']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Earle_Warren
# ['1914-07-01', '1995-06-04', 'Springfield', 'Springfield']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/James_P._Johnson
# ['1894-02-01', '1955-11-17', 'New Brunswick', 'Jamaica']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# ['1919-10-11', '1990-10-16', 'Pittsburgh', 'New York']
# [True, True, True, False]
# ['1919-10-11', '1990-10-16', 'http://dbpedia.org/resource/Pittsburgh', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://id.loc.gov/authorities/names/n85098932
# ['1919-05-19', '1990-01-08', 'Toronto', 'Palm Springs']
# [False, False, False, False]
# ['', '', '', '']
#
# ['1910-07-24', '1985-09-15', 'Mobile', 'New York']
# [False, True, True, True]
# ['1911-07-10', '1985-09-15', 'http://dbpedia.org/resource/Mobile,_Alabama', 'http://dbpedia.org/resource/New_York_City']
#
# ['1918-10-05', '1942-07-30', 'Chattanooga', 'Los Angeles']
# [True, True, True, False]
# ['1918-10-05', '1942-07-30', 'http://dbpedia.org/resource/Chattanooga,_Tennessee', 'http://dbpedia.org/resource/California']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Lawrence_Brown_(musician)
# ['1907-08-03', '1988-09-05', 'Lawrence', 'Los Angeles']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# ['1906-07-25', '1970-05-11', 'Cambridge', 'New York']
# [False, True, True, False]
# ['1907-07-25', '1970-05-11', 'http://dbpedia.org/resource/Cambridge,_Massachusetts', '']
#
# ['1907-02-22', '1967-09-07', 'Philadelphia', 'Los Angeles']
# [True, True, True, False]
# ['1907-02-22', '1967-09-07', 'http://dbpedia.org/resource/Philadelphia', 'http://dbpedia.org/resource/California']
#
# ['1900-12-31', '1984-04-23', 'Vega Baja', 'Inglewood']
# [False, True, True, False]
# ['1900-01-22', '1984-04-23', 'http://dbpedia.org/resource/Vega_Baja,_Puerto_Rico', 'http://dbpedia.org/resource/California']
#
# No query answer
# ['1909-03-27', '1973-09-20', 'Kansas City', 'Amsterdam']
# [True, True, True, False]
# ['1909-03-27', '1973-09-20', 'http://dbpedia.org/resource/Kansas_City,_Missouri', '']
#
# ['1912-05-13', '1988-03-20', 'Toronto', 'Cuernavaca']
# [True, True, False, True]
# ['1912-05-13', '1988-03-20', 'http://dbpedia.org/resource/Ontario', 'http://dbpedia.org/resource/Cuernavaca']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Nelson_Boyd
# ['1928-02-06', '1985-10', 'Camden', '']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/J.J._Johnson
# ['1924-01-22', '2001-02-04', 'Indianapolis', 'Indianapolis']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://id.loc.gov/authorities/names/n91049777
# ['1905-05-30', '1967-09-13', 'Crawfordsville', 'New York']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# ['1906-08-06', '1984-11-16', 'Xenia', 'New York']
# [True, True, True, False]
# ['1906-08-06', '1984-11-16', 'http://dbpedia.org/resource/Xenia,_Ohio', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/George_Morrow_(bassist)
# ['1925-08-15', '1992-05-26', 'Pasadena', 'Orlando']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# ['1908-04-20', '2002-08-31', 'Louisville', 'Manhattan']
# [True, True, True, False]
# ['1908-04-20', '2002-08-31', 'http://dbpedia.org/resource/Louisville,_Kentucky', '']
#
# No query answer
# No query answer
# ['1913-12-10', '1976-01-28', 'Chicago', 'New York']
# [True, True, False, False]
# ['1913-12-10', '1976-01-28', '', '']
#
# No query answer
# ['1917-02-21', '1965-03-08', 'Cleveland', 'New York']
# [True, True, True, False]
# ['1917-02-21', '1965-03-08', 'http://dbpedia.org/resource/Cleveland', '']
#
# ['1921-02-13', '1955-05-25', 'Detroit', 'Las Vegas']
# [True, True, False, True]
# ['1921-02-13', '1955-05-25', 'http://dbpedia.org/resource/Oklahoma', 'http://dbpedia.org/resource/Las_Vegas_Valley']
#
# No query answer
# ['1928-10-02', '2006-01-14', '', '']
# [True, True, False, False]
# ['1928-10-02', '2006-01-14', '', 'http://dbpedia.org/resource/Boca_Raton,_Florida']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://musicbrainz.org/artist/03df380a-665d-48c6-9cee-90c53f40ec3b
# ['1908-11-27', '', 'Atlanta', '']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://musicbrainz.org/artist/755d3c6a-9697-4204-803e-01333b29133e
# ['1872-08-10', '1972-12-03', '', 'New Braunfels']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/King_Oliver
# ['1885-05-11', '1938-04-08', 'Ascension Parish', 'Savannah']
# [False, False, False, False]
# ['', '', '', '']
#
# ['1935-04-22', '1969-01-04', 'Pittsburgh', 'New York']
# [True, True, False, True]
# ['1935-04-22', '1969-01-04', 'http://dbpedia.org/resource/Pennsylvania', 'http://dbpedia.org/resource/New_York_City']
#
# ['1929-01-20', '2020-05-24', 'Washington, D.C.', 'Manhattan']
# [True, True, True, False]
# ['1929-01-20', '2020-05-24', 'http://dbpedia.org/resource/Washington,_D.C.', 'http://dbpedia.org/resource/New_York_City']
#
# No query answer
# ['1926-07-03', '1997-12-21', 'Trenton', 'Philadelphia']
# [True, True, True, False]
# ['1926-07-03', '1997-12-21', 'http://dbpedia.org/resource/Trenton,_New_Jersey', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Bernie_Glow
# ['1926-02-06', '1982-05-08', 'New York', 'New York']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://id.loc.gov/authorities/names/nr91036407
# ['', '', '', '']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Jerome_Richardson
# ['1920-11-15', '2000-06-23', 'Oakland', 'Englewood']
# [False, False, False, False]
# ['', '', '', '']
#
# ['1921-02-06', '1983-03-16', 'Los Angeles', 'New York']
# [False, True, True, True]
# ['1921-06-02', '1983-03-16', 'http://dbpedia.org/resource/Los_Angeles', 'http://dbpedia.org/resource/New_York_City']
#
# No query answer
# ['1925-11-22', '2015-06-21', 'Queens', 'Boston']
# [True, True, True, False]
# ['1925-11-22', '2015-06-21', 'http://dbpedia.org/resource/Queens', '']
#
# No query answer
# No query answer
# ['1902-07-19', '1967-04-12', 'Memphis', 'New York']
# [True, False, False, True]
# ['1902-07-19', '', '', 'http://dbpedia.org/resource/New_York_City']
#
# No query answer
# ['1903-07-30', '1968-11-14', 'Danbury', 'New York']
# [True, True, True, False]
# ['1903-07-30', '1968-11-14', 'http://dbpedia.org/resource/Danbury,_Connecticut', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Keg_Johnson
# ['1908-11-09', '1967-11-08', 'Dallas', 'Chicago']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://musicbrainz.org/artist/d605b278-803b-4546-b318-268e3400a212
# ['1904-02-18', '1977-04-26', 'New York', 'New York']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# ['1907-12-18', '2009-08-14', 'Emporia', 'New York']
# [True, False, True, False]
# ['1907-12-18', '', 'http://dbpedia.org/resource/Emporia,_Virginia', '']
#
# ['1913-11-15', '2000-02-06', 'Tyler', 'Denver']
# [True, True, True, False]
# ['1913-11-15', '2000-02-06', 'http://dbpedia.org/resource/Tyler,_Texas', 'http://dbpedia.org/resource/Colorado']
#
# ['1924-07-06', '2009-02-14', 'Rock Falls', 'Los Angeles']
# [True, True, True, False]
# ['1924-07-06', '2009-02-14', 'http://dbpedia.org/resource/Rock_Falls,_Illinois', 'http://dbpedia.org/resource/California']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Buster_Cooper
# ['1929-04-04', '2016-05-13', 'St. Petersburg', 'St. Petersburg']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Jimmy_Jones_(pianist)
# ['1918-12-30', '1982-04-29', 'Memphis', 'Burbank']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/John_Lamb_(musician)
# ['1933-12-04', '', 'Vero Beach', '']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# ['1924-07-22', '1982-11-16', 'Newark', 'New York']
# [False, True, True, False]
# ['1922-07-19', '1982-11-16', 'http://dbpedia.org/resource/Newark,_New_Jersey', '']
#
# ['1917-11-26', '1989-04-15', 'Istanbul', 'New York']
# [True, False, False, True]
# ['1917-11-26', '1989-07-15', 'http://dbpedia.org/resource/Ottoman_Empire', 'http://dbpedia.org/resource/New_York_City']
#
# ['1907-08-08', '2003-07-12', 'Harlem', 'Los Angeles']
# [True, True, False, True]
# ['1907-08-08', '2003-07-12', 'http://dbpedia.org/resource/The_Bronx', 'http://dbpedia.org/resource/Los_Angeles']
#
# ['1909-10-17', '1981-01-29', 'East Orange', 'Columbus']
# [True, False, True, True]
# ['1909-10-17', '1981-01-09', 'http://dbpedia.org/resource/East_Orange,_New_Jersey', 'http://dbpedia.org/resource/Columbus,_Ohio']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://musicbrainz.org/artist/15f0322a-5ba3-4c40-b411-2445f7316b7a
# ['1910-02-24', '1945-03-19', 'Baltimore', 'New York']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# ['1898-05-14', '1975-07-14', 'Bunkie', 'New York']
# [False, True, False, False]
# ['', '1975-07-14', '', '']
#
# ['1890-03-28', '1967-12-29', 'Denver', 'Doylestown']
# [True, True, False, True]
# ['1890-03-28', '1967-12-29', 'http://dbpedia.org/resource/Colorado', 'http://dbpedia.org/resource/Doylestown,_Pennsylvania']
#
# ['1903-03-10', '1931-08-06', 'Davenport', 'Queens']
# [True, True, True, False]
# ['1903-03-10', '1931-08-06', 'http://dbpedia.org/resource/Davenport,_Iowa', 'http://dbpedia.org/resource/New_York_City']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Steve_Brown_(musician)
# ['1890-01-13', '1965-09-15', 'New Orleans', 'Detroit']
# [False, False, False, False]
# ['', '', '', '']
#
# ['1903-05-03', '1977-10-14', 'Tacoma', 'Alcobendas']
# [True, True, True, False]
# ['1903-05-03', '1977-10-14', 'http://dbpedia.org/resource/Tacoma,_Washington', 'http://dbpedia.org/resource/Community_of_Madrid']
#
# No query answer
# ['1932-12-15', '2021-05-08', 'Detroit', 'Detroit']
# [True, True, True, False]
# ['1932-12-15', '2021-05-08', 'http://dbpedia.org/resource/Detroit', '']
#
# No query answer
# No query answer
# ['1933-08-25', '', 'Newark', '']
# [True, False, True, False]
# ['1933-08-25', '', 'http://dbpedia.org/resource/Newark,_New_Jersey', '']
#
# No query answer
# No query answer
# ['1937-06-26', '', 'Philadelphia', '']
# [True, False, True, False]
# ['1937-06-26', '', 'http://dbpedia.org/resource/Philadelphia', '']
#
# No query answer
# No query answer
# ['1902-10-25', '1933-03-26', 'Philadelphia', 'New York']
# [True, True, False, False]
# ['1902-10-25', '1933-03-26', '', '']
#
# No query answer
# ['1918-09-21', '1988-03-01', 'Philadelphia', 'Philadelphia']
# [True, True, False, False]
# ['1918-09-21', '1988-03-01', 'http://dbpedia.org/resource/Pennsylvania', '']
#
# No query answer
# ['1921-08-04', '2010-03-28', 'Farmersville', 'Los Angeles']
# [True, True, True, False]
# ['1921-08-04', '2010-03-28', 'http://dbpedia.org/resource/Farmersville,_Texas', '']
#
# ['1925-08-15', '2007-12-23', 'Montreal', 'Ontario']
# [True, True, True, False]
# ['1925-08-15', '2007-12-23', 'http://dbpedia.org/resource/Montreal', 'http://dbpedia.org/resource/Mississauga']
#
# No query answer
# ['1905-02-10', '1939-06-16', 'Baltimore', 'Baltimore']
# [True, True, True, False]
# ['1905-02-10', '1939-06-16', 'http://dbpedia.org/resource/Baltimore', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://musicbrainz.org/artist/0adeb9ef-3db0-4768-9a84-cf4070276673
# ['', '1964', '', '']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Louis_Jordan
# ['1908-07-08', '1975-02-04', 'Brinkley', 'Los Angeles']
# [False, False, False, False]
# ['', '', '', '']
#
# ['1920-06-11', '1984-09-26', 'New York', 'Los Angeles']
# [True, True, True, False]
# ['1920-06-11', '1984-09-26', 'http://dbpedia.org/resource/New_York_City', 'http://dbpedia.org/resource/California']
#
# ['1919-03-19', '1978-11-18', 'Chicago', 'Queens']
# [True, True, True, False]
# ['1919-03-19', '1978-11-18', 'http://dbpedia.org/resource/Chicago', 'http://dbpedia.org/resource/New_York_City']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Budd_Johnson
# ['1910-12-14', '1984-10-20', 'Dallas', 'Kansas City']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# ['1919-01-01', '2005-07-29', 'Chicago', 'Los Angeles']
# [True, True, False, False]
# ['1919-01-01', '2005-07-29', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Chano_Pozo
# ['1915-01-17', '1948-12-02', 'La Habana', 'New York']
# [False, False, False, False]
# ['', '', '', '']
#
# ['1923-04-20', '2000-06-01', 'Harlem', 'New York']
# [True, False, False, True]
# ['1923-04-20', '2000-05-31', 'http://dbpedia.org/resource/New_York_City', 'http://dbpedia.org/resource/New_York_City']
#
# No query answer
# No query answer
# ['1921-09-21', '2013-11-25', 'Los Angeles', 'Manhattan']
# [False, True, False, False]
# ['1921-09-20', '2013-11-25', '', '']
#
# No query answer
# No query answer
# ['1940-04-12', '', 'Chicago', '']
# [True, False, True, False]
# ['1940-04-12', '', 'http://dbpedia.org/resource/Chicago', '']
#
# No query answer
# No query answer
# ['1947-02-22', '', 'Atlantic City', '']
# [True, False, True, False]
# ['1947-02-22', '', 'http://dbpedia.org/resource/Atlantic_City,_New_Jersey', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Isidore_Barbarin
# ['1871-09-24', '1960-06-12', 'New Orleans', 'New Orleans']
# [False, False, False, False]
# ['', '', '', '']
#
# ['1889-12-27', '1949-07-07', 'New Orleans', 'New Iberia']
# [False, True, False, False]
# ['1879-12-27', '1949-07-07', 'http://dbpedia.org/resource/Louisiana', 'http://dbpedia.org/resource/Louisiana']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/George_Lewis_(trombonist)
# ['1900-07-13', '1968-12-31', 'New Orleans', 'New Orleans']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# ['1900-10-24', '1959-06-05', 'New Orleans', 'New Orleans']
# [True, False, True, False]
# ['1900-10-24', '1959-06-06', 'http://dbpedia.org/resource/New_Orleans', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Jim_Robinson_(trombonist)
# ['1892-12-25', '1976-05-04', 'Plaquemines Parish', 'New Orleans']
# [False, False, False, False]
# ['', '', '', '']
#
# ['1916-03-06', '1992-03-08', 'Richmond County', 'Saugus, Santa Clarita']
# [True, True, False, True]
# ['1916-03-06', '1992-03-08', 'http://dbpedia.org/resource/Haynesville,_Virginia', 'http://dbpedia.org/resource/Saugus,_Santa_Clarita,_California']
#
# ['1923-02-27', '1990-04-25', 'Los Angeles', 'Philadelphia']
# [True, True, False, False]
# ['1923-02-27', '1990-04-25', 'http://dbpedia.org/resource/California', 'http://dbpedia.org/resource/Pennsylvania']
#
# No query answer
# ['1918-03-06', '1987-07-17', 'Tulsa', 'New York']
# [True, True, True, False]
# ['1918-03-06', '1987-07-17', 'http://dbpedia.org/resource/Tulsa,_Oklahoma', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://musicbrainz.org/artist/e4d7859f-42f9-42c9-8c0e-014d80a4dd15
# ['1921-01-29', '2000-06-05', 'Boston', 'Culver City']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Lee_Young
# ['1914-03-07', '2008-07-31', 'New Orleans', 'Los Angeles']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# ['1929-01-25', '', 'Philadelphia', '']
# [True, False, False, False]
# ['1929-01-25', '', 'http://dbpedia.org/resource/Pennsylvania', '']
#
# No query answer
# ['1922-09-07', '1992-07-04', 'New Orleans', 'New York']
# [True, True, True, False]
# ['1922-09-07', '1992-07-04', 'http://dbpedia.org/resource/New_Orleans', '']
#
# No query answer
# No query answer
# ['1920-08-03', '1971-07-08', 'New York', 'New York']
# [True, True, False, False]
# ['1920-08-03', '1971-07-08', '', '']
#
# No query answer
# No query answer
# No query answer
# ['1927-03-08', '', 'New York', '']
# [True, False, False, False]
# ['1927-03-08', '', '', '']
#
# ['1908-12-31', '1952-06-14', 'Winchester', 'Hollywood']
# [True, True, True, False]
# ['1908-12-31', '1952-06-14', 'http://dbpedia.org/resource/Winchester,_Virginia', 'http://dbpedia.org/resource/California']
#
# No query answer
# ['1922-01-15', '1997-05-14', 'Brooklyn', 'New York']
# [True, True, True, False]
# ['1922-01-15', '1997-05-14', 'http://dbpedia.org/resource/Brooklyn', '']
#
# No query answer
# ['1908-11-02', '1942-06-02', 'Hilbert', 'Manhattan']
# [True, True, True, False]
# ['1908-11-02', '1942-06-02', 'http://dbpedia.org/resource/Hilbert,_Wisconsin', '']
#
# ['1908-08-10', '1965-07-01', 'Terre Haute', 'New York']
# [True, True, True, False]
# ['1908-08-10', '1965-07-01', 'http://dbpedia.org/resource/Terre_Haute,_Indiana', 'http://dbpedia.org/resource/Caldwell,_New_Jersey']
#
# No query answer
# No query answer
# No query answer
# ['1945-06-04', '', 'Chicago', '']
# [True, False, False, False]
# ['1945-06-04', '', '', '']
#
# No query answer
# No query answer
# ['1923-11-24', '1957-07-16', 'Boston', 'Boston']
# [True, True, False, False]
# ['1923-11-24', '1957-07-16', '', '']
#
# ['1918-04-11', '2000', 'Nashville', 'New York']
# [False, False, False, False]
# ['1937-11-19', '2004-09-11', 'http://dbpedia.org/resource/Itta_Bena,_Mississippi', 'http://dbpedia.org/resource/Los_Angeles']
#
# ['1917-09-30', '1987-04-02', 'Brooklyn', 'Los Angeles']
# [True, True, False, False]
# ['1917-09-30', '1987-04-02', 'http://dbpedia.org/resource/New_York_City', 'http://dbpedia.org/resource/California']
#
# ['1924-04-06', '1998-11-30', 'Washington, D.C.', 'Seattle']
# [True, False, True, True]
# ['1924-04-06', '1988-11-30', 'http://dbpedia.org/resource/Washington,_D.C.', 'http://dbpedia.org/resource/Seattle']
#
# ['1927-02-02', '1991-06-06', 'Philadelphia', 'Malibu']
# [True, True, False, False]
# ['1927-02-02', '1991-06-06', 'http://dbpedia.org/resource/Pennsylvania', 'http://dbpedia.org/resource/California']
#
# ['1934-01-05', '2013-03-30', 'South Africa', 'Manhattan']
# [True, True, True, False]
# ['1934-01-05', '2013-03-30', 'http://dbpedia.org/resource/Union_of_South_Africa', 'http://dbpedia.org/resource/New_York_City']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://musicbrainz.org/artist/b2a298bc-c4ad-438b-8fc7-36002502706b
# ['', '', '', '']
# [False, False, False, False]
# ['', '', '', '']
#
# ['1910-01-23', '1953-05-16', 'Liberchies', 'Samois-sur-Seine']
# [True, True, False, True]
# ['1910-01-23', '1953-05-16', 'http://dbpedia.org/resource/Pont-à-Celles', 'http://dbpedia.org/resource/Samois-sur-Seine']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Bennie_Moten
# ['1894-11-13', '1935-04-02', 'Kansas City', 'Kansas City']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# ['1908-01-27', '1954-11-04', 'Dallas', 'New York']
# [True, False, True, False]
# ['1908-01-27', '1954-11-05', 'http://dbpedia.org/resource/Dallas', '']
#
# No query answer
# No query answer
# No query answer
# ['1927-04-27', '1994-11-30', '', 'Manhattan']
# [True, False, False, False]
# ['1927-04-27', '', '', '']
#
# No query answer
# ['1923-10-17', '2004-05-06', 'Muskogee', 'San Diego']
# [True, True, True, False]
# ['1923-10-17', '2004-05-06', 'http://dbpedia.org/resource/Muskogee,_Oklahoma', '']
#
# No query answer
# ['1912-04-11', '2012-01-20', 'New Orleans', 'Altadena']
# [True, True, False, False]
# ['1912-04-11', '2012-01-20', 'http://dbpedia.org/resource/Louisiana', '']
#
# No query answer
# ['1919-08-13', '2011-02-14', 'Battersea', 'New York']
# [True, True, True, False]
# ['1919-08-13', '2011-02-14', 'http://dbpedia.org/resource/Battersea', '']
#
# ['1923-02-27', '1997-07-29', 'New York', 'Ocean County']
# [True, True, True, False]
# ['1923-02-27', '1997-07-29', 'http://dbpedia.org/resource/New_York_City', 'http://dbpedia.org/resource/Jackson_Township,_New_Jersey']
#
# No query answer
# No query answer
# ['1900-07-29', '1964-11-30', 'West Virginia', 'New York']
# [True, False, True, False]
# ['1900-07-29', '', 'http://dbpedia.org/resource/Piedmont,_West_Virginia', '']
#
# No query answer
# ['1899-06-11', '1948-01-03', 'Savannah', 'New York']
# [False, False, False, True]
# ['1902-06-11', '1948-01-02', '', 'http://dbpedia.org/resource/New_York_City']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Joe_Smith_%28musician%29
# ['1902-06-28', '1937-12-02', 'Brown County', 'Central Islip']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Marky_Markowitz
# ['1923-12-11', '1986-11-11', '', '']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://musicbrainz.org/artist/19eea818-34bd-4250-ba77-8bc88dfd8774
# ['', '', '', '']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Earl_Swope
# ['1922-08-04', '1968-01-03', 'Hagerstown', 'Washington, D.C.']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# ['1905-11-16', '1973-08-04', 'Indiana', 'New York']
# [True, True, True, False]
# ['1905-11-16', '1973-08-04', 'http://dbpedia.org/resource/Goodland,_Indiana', '']
#
# ['1905-08-20', '1964-01-15', 'Vernon', 'New Orleans']
# [True, True, True, False]
# ['1905-08-20', '1964-01-15', 'http://dbpedia.org/resource/Vernon,_Texas', 'http://dbpedia.org/resource/Louisiana']
#
# ['1938-07-10', '1972-02-19', 'Philadelphia', 'New York']
# [True, True, False, True]
# ['1938-07-10', '1972-02-19', 'http://dbpedia.org/resource/Pennsylvania', 'http://dbpedia.org/resource/New_York_City']
#
# No query answer
# No query answer
# ['1902-10-12', '1967-11-16', 'Norfolk', 'Amityville']
# [True, False, True, False]
# ['1902-10-12', '', 'http://dbpedia.org/resource/Norfolk,_Virginia', '']
#
# ['1899-05-05', '1969-02-17', 'New Orleans', 'New Orleans']
# [True, True, False, True]
# ['1899-05-05', '1969-02-17', 'http://dbpedia.org/resource/Louisiana', 'http://dbpedia.org/resource/New_Orleans']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Lee_Blair
# ['1903-10-10', '1966-10-15', 'Savannah', 'New York']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Charlie_Holmes
# ['1910-01-27', '1985-09-18', 'Boston', 'Massachusetts']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# ['1902-08-06', '1963-12-11', 'Bocas del Toro', 'New York']
# [False, False, True, True]
# ['1902-08-05', '', 'http://dbpedia.org/resource/Bocas_Town,_Bocas_del_Toro', 'http://dbpedia.org/resource/New_York_City']
#
# No query answer
# ['1914-11-20', '1985-05-27', 'North Carolina', 'The Bronx']
# [True, True, True, False]
# ['1914-11-20', '1985-05-27', 'http://dbpedia.org/resource/Kinston,_North_Carolina', '']
#
# No query answer
# No query answer
# ['1906-10-10', '1978-07-12', 'New York', 'New York']
# [True, False, True, False]
# ['1906-10-10', '', 'http://dbpedia.org/resource/New_York_City', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Freddy_Robinson
# ['1901-02-20', '1984-04-11', 'Memphis', 'New York']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://dbpedia.org/resource/Bobby_Whitlock
# ['1931-01-21', '2015-06-29', 'Roosevelt', 'Long Beach']
# [False, False, False, False]
# ['', '', '', '']
#
# No query answer
# No query answer
# No query answer
# No query answer
# http://id.loc.gov/authorities/names/n80124239
# ['1897-05-23', '1971-12-22', 'Georgia', 'Chicago']
# [False, False, False, False]
# ['', '', '', '']
#
# ['1908-01-01', '1991-12-28', 'Boston', 'New York']
# [False, False, False, True]
# ['1941-08-07', '2021-01-11', 'http://dbpedia.org/resource/Montgomery,_Alabama', 'http://dbpedia.org/resource/New_York_City']
#
# 189

# %%
query_matches[0]
# Out:
# ['http://musicbrainz.org/artist/2e38e1de-2890-4620-8467-5b0bb4641cb9',
#  'http://dbpedia.org/resource/Milt_Jackson']

# %%
with open(OUTPUT_2,'w') as f:
    for i, pair in enumerate(query_matches):
        if i!=0: f.write('\n')
        a, b = pair
        f.write(f"<http://musicbrainz.org/artist/{a}> <owl:sameAs> {b}")
